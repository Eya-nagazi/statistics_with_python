# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt         
import seaborn as sns  
import os

# %%
pwd
# Out:
# 'C:\\Users\\eya\\desktop\\coursera python\\u'

# %%
df=pd.read_csv(r"C:\Users\eya\desktop\coursera python\final_project_duke\all_data.csv")
df.head(41)
# Out:
#    Ws Property Id profitable properties  Apt House         City group Kitchen  \
# 0            W103            profitable      house       Austin  W103       Y
# 1            W107            profitable      house       Austin  W107       Y
# 2            W108            profitable      house       Austin  W108       Y
# 3            W109            profitable  apartment       Austin  W109       Y
# 4            W110            profitable  apartment       Austin  W110       Y
# 5            W111            profitable      house       Austin  W111       Y
# 6            W112            profitable      house       Austin  W112       Y
# 7            W114            profitable  apartment       Austin  W114       Y
# 8            W115            profitable      house       Austin  W115       Y
# 9            W116            profitable      house       Austin  W116       Y
# 10           W118            profitable  apartment       Austin  W118       Y
# ...

# %%
df.shape
# Out:
# (41, 61)

# %%
df.head(0)
# Out:
# Empty DataFrame
# ...

# %%
df.columns
# Out:
# Index(['Ws Property Id', 'profitable properties', 'Apt House', 'City', 'group',
#        'Kitchen', 'Location',
#        'Net Change in Profits, each year thereafter (for next 4 years)  (bin)',
#        'number_bedrooms', 'Property Type', 'Shared', 'State', 'Zipcode',
#        '$ 90th-$10th', 'Change in Gross Rental Revenue',
#        'Change in Gross Rental Revenue fixe',
#        'Correct Forecast Occupancy Rate ', 'Correct Nightly $ Rent',
#        'Correct Nightly Rent Normalized to Percentile', 'Current Monthly Rent',
#        'Forecast ST annual Revenues After Transaction Fees',
#        'Forecast ST annual Revenues After Transaction Fees fixe',
#        'Forecast ST annual Revenues Before Transaction Fees', 'Interm Result1',
#        'Interm Result2', 'Interm Result3', 'LT Annual Revenues',
#        'model dynamic net change in cash flow conversion year ',
#        'model dynamic net change in cash flow year thereafter ',
#        'model dynamic net profits conversion year',
# ...

# %%
extract=df.loc[:,['Ws Property Id', 'Property Type','Location', 'group','City','State', 'Zipcode','Apt House','number_bedrooms',
       'Net Forecast Change in Cash Flow, Conversion Year ',
        'Net Change in Profits, Conversion year','Net Change in Profits, each year thereafter (for next 4 years) ',
                 'Net Change in Cash Flow, Each Year Thereafter (for next 4 years) ']]
extract.head()
# Out:
#   Ws Property Id Property Type Location group    City State  Zipcode  \
# 0           W103           R10   L15257  W103  Austin    TX    78702
# 1           W107           R10   L15260  W107  Austin    TX    78705
# 2           W108           R14   L15260  W108  Austin    TX    78705
# 3           W109            R2   L15264  W109  Austin    TX    78723
# 4           W110            R6   L15264  W110  Austin    TX    78723
#
#    Apt House number_bedrooms  \
# 0      house            1 BD
# 1      house            1 BD
# 2      house            2 BD
# 3  apartment            1 BD
# 4  apartment            2 BD
#
#    Net Forecast Change in Cash Flow, Conversion Year   \
# 0                                       -8442.800870
# 1                                       36983.041880
# 2                                       26515.737656
# 3                                      -11051.110808
# 4                                        9088.724813
#
# ...

# %%
extract_final=extract.rename(columns={"Ws Property Id":"Property ID","number_bedrooms":"Number Bedrooms",
                                      "Net Forecast Change in Cash Flow, Conversion Year ":"N.C Cash Flow,Conersion Year",
                        "Net Change in Profits, Conversion year":"N.C in Profits,Conversion Year",
                      "Net Change in Profits, each year thereafter (for next 4 years) ":"N.C in Profits Year thereafter",
                       "Net Change in Cash Flow, Each Year Thereafter (for next 4 years) ":"N.C Cash Flow,Year thereafter"})
extract_final.head(41)
# Out:
#    Property ID Property Type Location group         City State  Zipcode  \
# 0         W103           R10   L15257  W103       Austin    TX    78702
# 1         W107           R10   L15260  W107       Austin    TX    78705
# 2         W108           R14   L15260  W108       Austin    TX    78705
# 3         W109            R2   L15264  W109       Austin    TX    78723
# 4         W110            R6   L15264  W110       Austin    TX    78723
# 5         W111           R10   L15264  W111       Austin    TX    78723
# 6         W112           R14   L15264  W112       Austin    TX    78723
# 7         W114            R6   L15278  W114       Austin    TX    78744
# 8         W115           R10   L15278  W115       Austin    TX    78744
# 9         W116           R14   L15278  W116       Austin    TX    78744
# 10        W118            R6   L15280  W118       Austin    TX    78746
# 11        W119           R10   L15280  W119       Austin    TX    78746
# ...
